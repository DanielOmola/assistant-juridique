# %%
# %% [markdown]
# # 🔧 Diagnostic technique

# %% [code]
import os
os.environ["ASSISTANT_LOG_LEVEL"] = "DEBUG"
os.environ["SHOW_LOGS"] = "True"

# Afficher les logs
# !cat /content/drive/MyDrive/assistant-juridique/logs/assistant.log

# Tester le backend en mode debug
# %run /content/drive/MyDrive/assistant-juridique/01_backend_llm.ipynb
