# %% [markdown]
# # ACTIVATION BACKEND

# %%
# Dans le second notebook, exécutez le premier notebook
# avec gestion des espaces dans le chemin
# %run "/content/drive/MyDrive/assistant-juridique/01_backend_llm.ipynb"

# %% [markdown]
# # FRONTEND

# %%
creer_interface(llm_client)
# Out:
# HTML(value='<br>')
# ...
# HTML(value="<h1 style='color:#1a73e8'>🤖 Assistant Juridique IA</h1>")
# HTML(value='<hr>')
# HTML(value='<h3>🔑 Statut des clés API</h3>')
# HTML(value="<span style='color:green'>✅ Clés actives: GROQ</span>")
# HTML(value='<br>')
# HTML(value='<h3>🎛️ Modèle IA</h3>')
# Dropdown(description='🤖 Modèle:', layout=Layout(width='90%'), options=(('🟢 Gratuits (Groq) - Llama 3.3 70B (gr…
# HTML(value='<i>💡 Choisis un modèle selon tes clés API</i>')
# HTML(value='<br>')
# HTML(value='<h3>📎 Fichier</h3>')
# HTML(value='<b>📎 Glisse-dépose ton fichier :</b>')
# FileUpload(value={}, accept='.txt,.pdf,.docx,.md', description='📂 Choisir un fichier', layout=Layout(width='10…
# HTML(value="<span style='color:gray'>Aucun fichier</span>")
# HTML(value='<br>')
# HTML(value='<b>📁 Ou chemin dans Drive :</b>')
# Textarea(value='', layout=Layout(height='50px', width='80%'), placeholder='/content/drive/MyDrive/mon_dossier.…
# HTML(value='<br><hr>')
# ...
