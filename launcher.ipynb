# %%
# %% [markdown]
# # 🚀 Lancement de l'Assistant Juridique

# %% [code]
import os
import sys
import io

# Configuration silencieuse
os.environ["ASSISTANT_LOG_LEVEL"] = "ERROR"
os.environ["SHOW_LOGS"] = "False"

# Capturer les prints
original_stdout = sys.stdout
sys.stdout = io.StringIO()

# Lancer le backend
# %run /content/drive/MyDrive/assistant-juridique/01_backend_llm.ipynb

# Restaurer
sys.stdout = original_stdout

print("✅ Assistant prêt !")

# Afficher l'interface
# %run /content/drive/MyDrive/assistant-juridique/02_frontend.ipynb
