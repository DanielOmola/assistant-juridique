# %% [markdown]
# # 🤖 Juribot - Assistant Juridique IA
# **📄 Analyse | ⚖️ Conclusions | ✨ Rédaction | 📧 Email | 📜 Actes | 🔍 Dalloz | 🖊️ Tampon**
#
# ---

# %%
import os
import logging
# Configuration des logs AVANT tout import
os.environ["ASSISTANT_LOG_LEVEL"] = "INFO"  # DEBUG, INFO, WARNING, ERROR
os.environ["SHOW_LOGS"] = "False"  # True pour voir les logs dans la console

# %% [markdown]
# # 0 - MOUNT DRIVE

# %%
from google.colab import drive

# logger.info("📁 Montage de Google Drive...")


# 1. Réparer le répertoire courant
try:
    # Se déplacer dans /content (existe toujours)
    os.chdir('/content')
    # logger.info(f"✅ Répertoire courant: {os.getcwd()}")
except Exception as e:
    # logger.warning(f"⚠️ Répertoire courant: {os.getcwd()}")
    # Alternative: utiliser un chemin absolu
    os.environ['PWD'] = '/content'

def mount_google_drive(mount_point='/content/drive', force_remount=False):
    """Monte Google Drive"""
    try:
        import os
        if os.path.exists(mount_point) and not force_remount:
            if os.path.exists(os.path.join(mount_point, 'MyDrive')):
                print("✅ Drive déjà monté")
                return True

        drive.mount(mount_point, force_remount=force_remount)
        print(f"✅ Google Drive monté sur {mount_point}")
        # logger.info(f"✅ Drive monté sur {mount_point}")
        return True
    except Exception as e:
        print(f"❌ Erreur montage Drive: {str(e)}")
        return False
mount_google_drive()

# %%
import sys
# Importer et initialiser les logs
from utils.utils_logging import setup_logging, get_logger
# Importer et initialiser les logs
from utils.utils_logging import setup_logging, get_logger
setup_logging()
logger = get_logger(__name__)

# %%
sys.path.append("/content/drive/MyDrive/assistant-juridique")
logger.debug(f"PYTHONPATH: {sys.path}")
# Out:
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/content/drive/MyDrive/1_ASSISTANT_IA_AVOCAT', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/1_ASSISTANT_IA_AVOCAT']

# %% [markdown]
# # 1 - INSTALLATION DES BIBLIOTHÈQUES

# %%
logger.info("🚀 Démarrage du backend")
logger.info("📦 Installation des bibliothèques...")
# ============================================
# 1. INSTALLATION DES BIBLIOTHÈQUES
# ============================================
# !pip install -q openai
# !pip uninstall openai -y
# !pip install openai>=1.0.0
# !pip install -q PyPDF2
# !pip install -q python-docx
# !pip install -q ipywidgets
# !pip install -e /content/drive/MyDrive/assistant-juridique
# Optionnel : pour les autres modèles (installe seulement ce dont tu as besoin)
# !pip install -q anthropic      # Pour Claude
# !pip install -q groq           # Pour Groq (gratuit)
# !pip install -q mistralai      # Pour Mistral
# !pip install -q google-generativeai  # Pour Gemini
logger.info("✅ Bibliothèques installées")
print("✅ Bibliothèques installées")
# Out:
# Obtaining file:///content/drive/MyDrive/1_ASSISTANT_IA_AVOCAT
#   Preparing metadata (setup.py) ... done
# Installing collected packages: assistant_ia_avocat
#   Attempting uninstall: assistant_ia_avocat
#     Found existing installation: assistant_ia_avocat 0.1
#     Uninstalling assistant_ia_avocat-0.1:
#       Successfully uninstalled assistant_ia_avocat-0.1
#   Running setup.py develop for assistant_ia_avocat
# Successfully installed assistant_ia_avocat-0.1
# ✅ Bibliothèques installées

# %% [markdown]
# # 2 - CONFIGURATION DES MODELES

# %%
# Test d'importation
import openai
import PyPDF2
import docx
from IPython.display import display
# from utils import mount_google_drive
from utils.config_llm import get_api_keys, get_modele_actif
from utils.config_clients import LLM_Client
from utils.utils_action_analyser_document import analyser_document
from utils.utils_action_preparer_email import preparer_email
from utils.utils_action_preparer_conclusion import preparer_conclusion
from utils.utils_action_ameliorer_redaction import ameliorer_redaction
from utils.utils_save_file import *
from utils.utils_recherche_genial import *
from utils.utils_create_interface import creer_interface
from utils.utils_action_rediger_acte import *
from utils.utils_tampon import (
    charger_config_tampon,
    sauvegarder_config_tampon,
    generer_tampon,
    appliquer_tampon,
    appliquer_tampon_fichier
)
logger.info("✅ Tous les modules essentiels sont importés")
print("✅ Tous les modules essentiels sont importés")
print("🚀 Tu peux continuer avec la cellule suivante")

modele_actif, message, MODELES_DISPONIBLES, API_KEYS = get_modele_actif()
logger.info(f"🎯 Modèle actif: {modele_actif}")
logger.debug(f"API KEYS disponibles: {[k for k, v in API_KEYS.items() if v]}")
# Out:
# ✅ Fonctions IA prêtes avec sélection de modèle
# ✅ Fonctions de sauvegarde prêtes
# ✅ Tous les modules essentiels sont importés
# 🚀 Tu peux continuer avec la cellule suivante
# 🔑 Chargement des clés API...
# ✅ GROQ_API_KEY → groq: gsk_4VlzkS... (caché)
# ⚠️ OPENAI_API_KEY: clé vide ou non configurée
# ⚠️ ANTHROPIC_API_KEY: clé vide ou non configurée
# ⚠️ MISTRAL_API_KEY: clé vide ou non configurée
# ⚠️ GOOGLE_API_KEY: clé vide ou non configurée
#
# ========================= API_KEYS =========================
# 	{'openai': None, 'anthropic': None, 'groq': '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', 'mistral': None, 'google': None}
#
# ========================= modele_actif =========================
# 	llama-3.3-70b-versatile

# %%
llm_client = LLM_Client(modele_actif, API_KEYS, MODELES_DISPONIBLES)
logger.info("✅ LLM Client initialisé")
# Out:
# ✅ Client Groq initialisé
# Test Groq: Bonjour, je suis prêt !
#
# ==================================================
# ✅ Configuration multi-modèles prête !
# 📊 Modèles disponibles : 9
# 🎯 Modèle par défaut: llama-3.3-70b-versatile
# ==================================================

# %% [markdown]
# # 3 - TEST MODELE ACTIF

# %%
logger.info("🧪 Test du modèle actif...")
text = """
Un client affirme avoir été licencié sans cause réelle et sérieuse.

Il indique ne pas avoir reçu d’avertissement préalable.

L’employeur évoque une insuffisance professionnelle.
"""
logger.debug(f"Texte de test: {len(text)} caractères")
analyse_documentaire = analyser_document(text, llm_client)
# print(analyse_documentaire)

ameliorer_redaction = ameliorer_redaction(analyse_documentaire, llm_client)
# print(ameliorer_redaction)

email = preparer_email(ameliorer_redaction, llm_client)
# print(email)

logger.info("✅ Test terminé")
# Out:
# **RÉSUMÉ**
# Le client affirme avoir été licencié sans cause réelle et sérieuse par son employeur, qui invoque une insuffisance professionnelle. Le client conteste cette décision, affirmant ne pas avoir reçu d'avertissement préalable. Cette situation soulève des questions sur la régularité du licenciement et les droits du salarié. Il est nécessaire de vérifier les faits et les procédures suivies par l'employeur pour déterminer si le licenciement est justifié. Le client peut avoir des droits à des indemnités ou à une réintégration.
#
# **POINTS CLÉS**
# * Licenciement sans cause réelle et sérieuse
# * Insuffisance professionnelle invoquée par l'employeur
# * Absence d'avertissement préalable
# * Contestation de la décision de licenciement par le client
# * Droits du salarié en cas de licenciement abusif
# * Procédure de licenciement et respect des formalités légales
#
# **RISQUES JURIDIQUES**
# * Le licenciement sans cause réelle et sérieuse peut être considéré comme abusif, ce qui pourrait entraîner des conséquences juridiques pour l'employeur, telles que des indemnités pour le salarié.
# * L'absence d'avertissement préalable peut être considérée comme une irrégularité dans la procédure de licenciement, ce qui pourrait invalider la décision de licenciement.
# * L'employeur peut être tenu responsable de dommages et intérêts si le licenciement est jugé abusif.
#
# **RECOMMANDATIONS**
# * Vérifier les faits et les procédures suivies par l'employeur pour déterminer si le licenciement est justifié.
# * Examiner les documents et les preuves disponibles pour évaluer la cause réelle et sérieuse du licenciement.
# * Étudier les droits du salarié en cas de licenciement abusif et les possibilités de recours.
# * Considérer la possibilité de négocier une transaction ou une indemnité pour le client.
# * Préparer un recours en justice si nécessaire pour défendre les droits du client.
# **RÉSUMÉ**
# Le client allègue avoir été licencié sans cause réelle et sérieuse par son employeur, qui invoque une insuffisance professionnelle. Le client conteste cette décision, affirmant ne pas avoir reçu d'avertissement préalable. Cette situation soulève des questions sur la régularité du licenciement et les droits du salarié. Il est nécessaire de vérifier les faits et les procédures suivies par l'employeur pour déterminer si le licenciement est justifié. Le client peut avoir des droits à des indemnités ou à une réintégration.
#
# **POINTS CLÉS**
# * Licenciement sans cause réelle et sérieuse
# * Insuffisance professionnelle invoquée par l'employeur
# * Absence d'avertissement préalable
# * Contestation de la décision de licenciement par le client
# * Droits du salarié en cas de licenciement abusif
# * Procédure de licenciement et respect des formalités légales
#
# **RISQUES JURIDIQUES**
# * Le licenciement sans cause réelle et sérieuse peut être considéré comme abusif, ce qui pourrait entraîner des conséquences juridiques pour l'employeur, telles que des indemnités pour le salarié.
# * L'absence d'avertissement préalable peut être considérée comme une irrégularité dans la procédure de licenciement, ce qui pourrait invalider la décision de licenciement.
# * L'employeur peut être tenu responsable de dommages et intérêts si le licenciement est jugé abusif.
#
# **RECOMMANDATIONS**
# * Vérifier les faits et les procédures suivies par l'employeur pour déterminer si le licenciement est justifié.
# * Examiner les documents et les preuves disponibles pour évaluer la cause réelle et sérieuse du licenciement.
# * Étudier les droits du salarié en cas de licenciement abusif et les possibilités de recours.
# * Considérer la possibilité de négocier une transaction ou une indemnité pour le client.
# * Préparer un recours en justice si nécessaire pour défendre les droits du client.
# Objet : Suivi de votre dossier de licenciement
#
# Cher(e) [Nom du client],
#
# Je vous écris pour vous fournir une mise à jour sur votre dossier de licenciement et vous présenter les éléments clés que nous avons identifiés jusqu'à présent. Comme vous le savez, vous avez été licencié par votre employeur pour insuffisance professionnelle, mais vous contestez cette décision, affirmant ne pas avoir reçu d'avertissement préalable.
#
# Le licenciement sans cause réelle et sérieuse est un sujet complexe qui soulève des questions sur la régularité de la procédure et les droits du salarié. Les points clés de votre dossier sont les suivants :
# * Le licenciement sans cause réelle et sérieuse
# * L'insuffisance professionnelle invoquée par l'employeur
# * L'absence d'avertissement préalable
# * La contestation de la décision de licenciement par votre part
# * Les droits du salarié en cas de licenciement abusif
# * La procédure de licenciement et le respect des formalités légales
#
# Il est important de noter que le licenciement sans cause réelle et sérieuse peut être considéré comme abusif, ce qui pourrait entraîner des conséquences juridiques pour l'employeur, telles que des indemnités pour le salarié. L'absence d'avertissement préalable peut également être considérée comme une irrégularité dans la procédure de licenciement, ce qui pourrait invalider la décision de licenciement. En outre, l'employeur peut être tenu responsable de dommages et intérêts si le licenciement est jugé abusif.
#
# En conséquence, nous recommandons de :
# * Vérifier les faits et les procédures suivies par l'employeur pour déterminer si le licenciement est justifié
# * Examiner les documents et les preuves disponibles pour évaluer la cause réelle et sérieuse du licenciement
# * Étudier les droits du salarié en cas de licenciement abusif et les possibilités de recours
# * Considérer la possibilité de négocier une transaction ou une indemnité pour vous
# * Préparer un recours en justice si nécessaire pour défendre vos droits
#
# Nous sommes convaincus que nous pouvons vous aider à défendre vos droits et à obtenir une issue favorable à votre dossier. Nous vous tiendrons informé de l'évolution de votre dossier et nous sommes à votre disposition pour répondre à toutes vos questions.
#
# Cordialement,
#
# [Votre nom]
# Avocat
# [Votre cabinet d'avocats]

# %% [markdown]
# # ========== CLIENTS API ==========

# %%
# ! cp /content/drive/MyDrive/assistant-juridique/mon_assistant_juridique.ipynb /content/drive/MyDrive/assistant-juridique/01_backend_llm.ipynb
