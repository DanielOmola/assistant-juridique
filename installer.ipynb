# %%
# %% [markdown]
# # ⚖️ Installation de l'Assistant Juridique IA
# 
# **Cliquez sur "Run All" (⌘+F9 / Ctrl+F9)**
# 
# L'installation est entièrement automatique.

# %% [code]
import os
from google.colab import drive

print("🚀 Assistant Juridique IA - Installation")
print("=" * 50)
print("")

# 1. Monter Google Drive
print("📁 Montage de Google Drive...")
drive.mount('/content/drive')

# Vérifier que Drive est accessible
if not os.path.exists("/content/drive/MyDrive"):
    print("❌ Erreur : Drive non accessible")
    exit(1)
print("✅ Drive monté avec succès")

# 2. Supprimer l'ancien script si nécessaire
if os.path.exists("deploy.sh"):
    os.remove("deploy.sh")
    print("🗑️ Ancien script supprimé")

# 3. Télécharger et exécuter le script d'installation
print("📥 Téléchargement du script d'installation...")
# !wget --no-cache -q https://raw.githubusercontent.com/DanielOmola/assistant-juridique/main/deploy.sh
# !chmod +x deploy.sh
print("🚀 Lancement de l'installation...")
# !./deploy.sh

# %% [code]
from IPython.display import display, HTML

display(HTML("""
<div style="background: #e8f0fe; padding: 20px; border-radius: 10px; text-align: center;">
    <h2 style="color: #1a73e8;">✅ Installation terminée !</h2>
    <hr>
    <p>📁 <strong>Dossier d'installation :</strong><br>
    <code>/content/drive/MyDrive/assistant-juridique/</code></p>
    <hr>
    <p>🚀 <strong>Pour lancer l'assistant :</strong></p>
    <ol style="text-align: left;">
        <li>Ouvrez votre <strong>Google Drive</strong></li>
        <li>Allez dans le dossier <strong>assistant-juridique/notebooks</strong></li>
        <li>Double-cliquez sur <strong>01_backend_llm.ipynb</strong></li>
        <li>Dans Colab : <strong>Runtime → Run all</strong></li>
        <li>Double-cliquez sur <strong>02_frontend.ipynb</strong></li>
        <li>Dans Colab : <strong>Runtime → Run all</strong></li>
    </ol>
    <hr>
    <p>🔧 <strong>Configuration initiale (obligatoire) :</strong></p>
    <ul style="text-align: left;">
        <li>Ouvrez <code>assistant-juridique/config/api_keys.yaml</code></li>
        <li>Ajoutez votre clé <strong>GROQ_API_KEY</strong> (gratuite sur console.groq.com)</li>
        <li>Ouvrez <code>assistant-juridique/config/tampon_config.yaml</code></li>
        <li>Personnalisez vos informations (nom, barreau, etc.)</li>
    </ul>
</div>
"""))
