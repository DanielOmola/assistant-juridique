# %%
# %% [markdown]
# # 🚀 Installation Assistant Juridique IA
#
# Cliquez sur **Run All** (⌘+F9 / Ctrl+F9) pour installer automatiquement

# %% [code]
import subprocess
import sys
import os

print("🚀 Démarrage de l'installation...")
print("")

# Télécharger et exécuter le script
# !wget -q https://raw.githubusercontent.com/DanielOmola/assistant-juridique/main/deploy.sh
# !chmod +x deploy.sh
# !./deploy.sh

# %% [code]
from IPython.display import display, HTML

display(HTML("""
<div style="text-align:center; padding:30px; background:#e8f0fe; border-radius:10px; margin:20px">
    <h2 style="color:#1a73e8">✅ Installation terminée !</h2>
    <p style="font-size:16px">Votre Assistant Juridique IA est prêt à l'emploi.</p>
    <hr>
    <p style="text-align:left">
        <b>📋 Prochaines étapes :</b><br><br>
        1. 📁 Dans le panneau de gauche, ouvrez <b>assistant-juridique/01_backend_llm.ipynb</b><br>
        2. 🚀 Exécutez toutes les cellules (Runtime → Run all)<br>
        3. 🎯 Ouvrez <b>02_frontend.ipynb</b> et exécutez-le<br>
        4. ⚙️ Personnalisez votre tampon dans <b>config/tampon_config.yaml</b><br><br>
        <b>💡 Besoin d'aide ?</b> Consultez la documentation ou contactez votre support.
    </p>
    <hr>
    <button onclick="google.colab.kernel.restart()" style="background:#1a73e8; color:white; padding:10px 20px; border:none; border-radius:5px; cursor:pointer">
        🔄 Redémarrer le kernel
    </button>
</div>
"""))
