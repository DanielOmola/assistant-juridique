# %%
# !pip install -e /content/drive/MyDrive/assistant-juridique

# %%
from utils.install_package_from_wheels import install_from_github
install_from_github()
from utils.legal_agent import LegalResearchAgent, LangChainLLMAdapter
